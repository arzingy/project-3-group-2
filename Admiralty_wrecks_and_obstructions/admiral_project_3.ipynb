# %%
# Project 3 - shipwrecks. (Testing datasets)
# Testing Admiralty dataset: Wrecks and Obstructions Shapefiles
#An extensive data set containing over 94,000 charted, uncharted, live and dead wrecks and obstructions from around the world. Updated on a quarterly basis
#Updated Jan 2025
#(https://datahub.admiralty.co.uk/portal/home/item.html?id=4dbf2ace22bf4f9785fb445d0593bc2c)

# %%

import geopandas as gpd

points = gpd.read_file("Points.shp")
areas = gpd.read_file("Areas.shp")
# Out:
# ---------------------------------------------------------------------------
# DataSourceError                           Traceback (most recent call last)
# Cell In[4], line 11
#       1 # Project 3 - shipwrecks. (Testing datasets)
#       2 # Testing Admiralty dataset: Wrecks and Obstructions Shapefiles
#       3 #An extensive data set containing over 94,000 charted, uncharted, live and dead wrecks and obstructions from around the world. Updated on a quarterly basis
#    (...)
#       6
#       7 # %%
#       9 import geopandas as gpd
# ---> 11 points = gpd.read_file("Points.shp")
#      12 areas = gpd.read_file("Areas.shp")
#
# File /opt/anaconda3/envs/dev/lib/python3.9/site-packages/geopandas/io/file.py:294, in _read_file(filename, bbox, mask, columns, rows, engine, **kwargs)
#     291             from_bytes = True
#     293 if engine == "pyogrio":
# --> 294     return _read_file_pyogrio(
#     295         filename, bbox=bbox, mask=mask, columns=columns, rows=rows, **kwargs
# ...

# %%
points.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 points.head()
#
# NameError: name 'points' is not defined

# %%
areas.head()
# Out:
#   wreck_id wreck_cate obstructio status classifica                 position  \
# 0    85167       None  foul area   None       None    33 30.735 N,35 19.7 E
# 1    85171       None  foul area   None       None  33 30.724 N,35 20.068 E
# 2    85173       None  foul area   None       None  33 30.746 N,35 20.306 E
# 3    85179       None  foul area   None       None  33 30.509 N,35 20.296 E
# 4    85181       None  foul area   None       None   33 30.425 N,35 20.32 E
#
#       latitude    longitude horizontal  \
# 0  33 30.735 N    35 19.7 E      WGD 2
# 1  33 30.724 N  35 20.068 E      WGD 2
# 2  33 30.746 N  35 20.306 E      WGD 2
# 3  33 30.509 N  35 20.296 E      WGD 2
# 4  33 30.425 N   35 20.32 E      WGD 2
#
#                                               limits  ... last_senso  \
# 0  4,18 35.3278197,33.5126169 35.3280497,33.51269...  ...       None
# 1  4,66 35.3347026,33.5123846 35.3347252,33.51224...  ...       None
# ...
